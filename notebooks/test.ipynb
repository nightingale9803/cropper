# %%
import cv2 as cv
import numpy as np
from math import *
from PIL import Image
from matplotlib import pyplot as plt

import os, sys
sys.path.append("..")

from modules.cropper import *

# %%
img_path = r'../test/test-color.jpg'
binary = RubbingCropper(img_path).binary

# %%
Image.fromarray(binary)
# Out:
# <PIL.Image.Image image mode=L size=1856x1392>
